# %% [markdown]
# <a href="https://colab.research.google.com/github/Ecamara888/cybersecurity-agentic/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python /content/lab02.py
# Out:
# === PART 1: Hello World ===
# Hello world
#
# === PART 2: All Times Tables ===
# This is the 1 times table:
# 1 times 1 is 1
# 1 times 2 is 2
# 1 times 3 is 3
# 1 times 4 is 4
# 1 times 5 is 5
# 1 times 6 is 6
# 1 times 7 is 7
# 1 times 8 is 8
# 1 times 9 is 9
# 1 times 10 is 10
# 1 times 11 is 11
# 1 times 12 is 12
# This is the 2 times table:
# 2 times 1 is 2
# 2 times 2 is 4
# 2 times 3 is 6
# 2 times 4 is 8
# 2 times 5 is 10
# 2 times 6 is 12
# 2 times 7 is 14
# 2 times 8 is 16
# 2 times 9 is 18
# 2 times 10 is 20
# 2 times 11 is 22
# 2 times 12 is 24
# This is the 3 times table:
# 3 times 1 is 3
# 3 times 2 is 6
# 3 times 3 is 9
# 3 times 4 is 12
# 3 times 5 is 15
# 3 times 6 is 18
# 3 times 7 is 21
# 3 times 8 is 24
# 3 times 9 is 27
# 3 times 10 is 30
# 3 times 11 is 33
# 3 times 12 is 36
# This is the 4 times table:
# 4 times 1 is 4
# 4 times 2 is 8
# 4 times 3 is 12
# 4 times 4 is 16
# 4 times 5 is 20
# 4 times 6 is 24
# 4 times 7 is 28
# 4 times 8 is 32
# 4 times 9 is 36
# ...
